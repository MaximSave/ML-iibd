# %%
pip install xtcocotools
# Out:
# ...
#   Using cached xtcocotools-1.14.3-cp310-cp310-win_amd64.whl.metadata (376 bytes)
# ...
# Using cached xtcocotools-1.14.3-cp310-cp310-win_amd64.whl (88 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mmdet
# Out:
# ...
#
#   Using cached mmdet-3.3.0-py3-none-any.whl.metadata (29 kB)
# ...
#   Using cached pycocotools-2.0.10-cp310-cp310-win_amd64.whl.metadata (1.3 kB)
# ...
#   Using cached shapely-2.1.1-cp310-cp310-win_amd64.whl.metadata (7.0 kB)
# ...
#   Using cached terminaltables-3.1.10-py2.py3-none-any.whl.metadata (3.5 kB)
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
# Using cached mmdet-3.3.0-py3-none-any.whl (2.2 MB)
# Using cached pycocotools-2.0.10-cp310-cp310-win_amd64.whl (80 kB)
# Using cached shapely-2.1.1-cp310-cp310-win_amd64.whl (1.7 MB)
# Using cached terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# ...
#
#    ---------------- ----------------------- 2/5 [shapely]
#    ---------------- ----------------------- 2/5 [shapely]
#    -------------------------------- ------- 4/5 [mmdet]
#    -------------------------------- ------- 4/5 [mmdet]
#    -------------------------------- ------- 4/5 [mmdet]
# ...

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from mmengine.config import Config
from mmpose.apis import inference_topdown, init_model
from mmpose.structures import merge_data_samples
# Out:
# C:\Users\maxim\anaconda3\envs\mmpose\lib\site-packages\mmengine\utils\package_utils.py:48: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution

# %%
pip install mmcv==2.1.0
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mmcv
print(mmcv.__version__)
# Out:
# 2.1.0

# %%
import torch
from mmpose.apis import init_model

# %%
pose_config = "C:/Users/maxim/p2025/mmpose/configs/hand_2d_keypoint/topdown_heatmap/onehand10k/td-hm_hrnetv2-w18_udp-8xb64-210e_onehand10k-256x256.py"

pose_checkpoint = "https://download.openmmlab.com/mmpose/hand/hrnet_w32_onehand10k_256x256-dbb5f44c_20200708.pth"

model = init_model(pose_config, pose_checkpoint, device='cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 5
#       1 pose_config = "C:/Users/maxim/p2025/mmpose/configs/hand_2d_keypoint/topdown_heatmap/onehand10k/td-hm_hrnetv2-w18_udp-8xb64-210e_onehand10k-256x256.py"
#       3 pose_checkpoint = "https://download.openmmlab.com/mmpose/hand/hrnet_w32_onehand10k_256x256-dbb5f44c_20200708.pth"
# ----> 5 model = init_model(pose_config, pose_checkpoint, device='cuda' if torch.cuda.is_available() else 'cpu')
#
# File c:\users\maxim\p2025\mmpose\mmpose\apis\inference.py:104, in init_model(config, checkpoint, device, cfg_options)
#     101 if scope is not None:
#     102     init_default_scope(scope)
# --> 104 model = build_pose_estimator(config.model)
#     105 model = revert_sync_batchnorm(model)
#     106 # get dataset_meta in this priority: checkpoint > config > default (COCO)
#
# ...

# %%
import torch
print(torch.__version__)
print(torch.version.cuda)
# Out:
# 2.5.1
# None

# %%
name_video = "10_10052025180232_4be19464-2205-11ed-b24c-b469216ca443.mp4"

video_path = "C:/Users/maxim/p2025/videos/{name_video}"
cap = cv2.VideoCapture(video_path)

frames = []
while True:
    ret, frame = cap.read()
    if not ret:
        break
    frames.append(frame)

cap.release()
print(f"Всего кадров: {len(frames)}")
