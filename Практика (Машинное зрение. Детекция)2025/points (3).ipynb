# %%
import numpy as np
import pandas as pd
import pathlib
from keras import layers
import keras
import tensorflow as tf
from sklearn.model_selection import train_test_split
import sklearn
import matplotlib.pyplot as plt
import plotly.express as px
from matplotlib.animation import FuncAnimation
from sklearn.linear_model import LinearRegression
import cv2
from IPython.display import HTML

# %%
ds_path = pathlib.Path("points")

# %%
path = list((ds_path / "0").glob("*.npy"))[0]
print(path)

points = np.load(path)
# Out:
# points\0\100_10052025191422_0315b142-246b-11ed-a221-e82aea2c97f4_3dkeypoints.npy

# %% [markdown]
# # Смотрим скелет

# %%
SKELETON = """
0-1
1-2
2-3
3-20
4-5
5-6
6-7
7-20
8-9
9-10
10-11
11-20
12-13
13-14
14-15
15-20
16-17
17-18
17-19
19-20
"""
SKELETON = SKELETON.strip().split("\n")
SKELETON = [tuple(map(int, i.split("-"))) for i in SKELETON]

# %%
def show_skeleton(frames):
    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')
    
    scatter = ax.scatter([], [], [], c='b', s=50)
    skeleton_lines = [ax.plot([], [], [], 'r-', linewidth=2)[0] for _ in SKELETON]
    
    all_coords = frames.reshape(-1, 3)
    ax.set_xlim(np.min(all_coords[:, 0]), np.max(all_coords[:, 0]))
    ax.set_ylim(np.min(all_coords[:, 1]), np.max(all_coords[:, 1]))
    ax.set_zlim(np.min(all_coords[:, 2]), np.max(all_coords[:, 2]))
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    
    
    def update_skeleton(frame):
        frame_data = frames[frame]
        x, y, z = frame_data[:, 0], frame_data[:, 1], frame_data[:, 2]
        
        scatter._offsets3d = (x, y, z)
        
        # Update skeleton lines
        for i, (start_idx, end_idx) in enumerate(SKELETON):
            skeleton_lines[i].set_data(
                [x[start_idx], x[end_idx]],
                [y[start_idx], y[end_idx]]
            )
            skeleton_lines[i].set_3d_properties(
                [z[start_idx], z[end_idx]]
            )
        
        ax.set_title(f'Frame: {frame}')
        return [scatter] + skeleton_lines
    
    ani = FuncAnimation(fig, update_skeleton, frames=len(frames), interval=50, blit=False)
    return HTML(ani.to_jshtml())

# %% [markdown]
# # Загружаем датасет

# %%
ds_path = pathlib.Path("points")
classes = ["0", "1", "2", "3"]

filenames = []
X_orig = []
X = []
y = []

for cls in classes:
    cls_dir = ds_path / cls
    for file_path in cls_dir.glob("*.npy"):
        pts = np.load(file_path)
        X_orig.append(pts)
        filenames.append(file_path.stem)
        # print(pts)
        pts = pts.reshape(-1, 21 * 3)  # Решейпим 21 3д точки в один вектор чисел на 63 элемента
        X.append(pts)
        y.append(int(cls))
y = np.array(y)

# Добавляем паддинг входным данным, чтобы они были одинакового размера
X = tf.keras.utils.pad_sequences(X, padding="post")

# Нормализуем
X = X.astype(float)
X /= X.max()


# Разбиваем на train/test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)
print("Train:", len(X_train))
print("Test:", len(X_test))

print("input_shape =", X.shape[1:])
# Out:
# Train: 445
# Test: 50
# input_shape = (629, 63)

# %% [markdown]
# # RNN

# %%
# Делаем датасет из tf
def augment(x):  # небольшая аугментация со случайным смещением точек
    mul = tf.random.uniform(shape=x.shape, minval=0.99, maxval=1.01, dtype=tf.float64)
    return x * mul

train = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train = train.map(lambda x, y: (augment(x), y))
train = train.shuffle(1000)
train = train.batch(8)

test = tf.data.Dataset.from_tensor_slices((X_test, y_test))
test = test.batch(8)

# %%
model = keras.Sequential([
    layers.Masking(mask_value=0.0, input_shape=X.shape[1:]),
    layers.LSTM(128, input_shape=X.shape[1:], activation='tanh', return_sequences=True),  # Возвращает (629, 128)
    layers.BatchNormalization(),
    layers.Dropout(0.1),
    
    layers.LSTM(128, activation='tanh', return_sequences=False),  # Возвращает вектор 128
    layers.BatchNormalization(),
    layers.Dropout(0.1),

    # LSTM(128, activation='tanh', return_sequences=False),  # Возвращает вектор 128
    # BatchNormalization(),
    # Dropout(0.1),
    
    layers.Dense(32, activation='relu'),
    layers.Dropout(0.1),
    layers.Dense(4, activation='softmax'),
])

model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer="Adam",
    metrics=['accuracy'],
)

hist = model.fit(
    train,
    epochs=50,
    validation_data=test,
)
# Out:
# Epoch 1/50
# 55/55 [==============================] - 21s 329ms/step - loss: 1.6244 - accuracy: 0.2938 - val_loss: 1.3612 - val_accuracy: 0.3469
# Epoch 2/50
# 55/55 [==============================] - 16s 281ms/step - loss: 1.3447 - accuracy: 0.3804 - val_loss: 1.3848 - val_accuracy: 0.2449
# Epoch 3/50
# 55/55 [==============================] - 17s 314ms/step - loss: 1.3085 - accuracy: 0.3941 - val_loss: 1.4330 - val_accuracy: 0.1837
# Epoch 4/50
# 55/55 [==============================] - 16s 281ms/step - loss: 1.2590 - accuracy: 0.4169 - val_loss: 1.4197 - val_accuracy: 0.3469
# Epoch 5/50
# 55/55 [==============================] - 18s 322ms/step - loss: 1.1366 - accuracy: 0.4761 - val_loss: 1.3629 - val_accuracy: 0.3673
# Epoch 6/50
# 55/55 [==============================] - 15s 275ms/step - loss: 1.1356 - accuracy: 0.4897 - val_loss: 1.3605 - val_accuracy: 0.3265
# Epoch 7/50
# 55/55 [==============================] - 18s 319ms/step - loss: 1.1661 - accuracy: 0.4943 - val_loss: 1.4205 - val_accuracy: 0.4082
# Epoch 8/50
# 55/55 [==============================] - 16s 282ms/step - loss: 1.1022 - accuracy: 0.5011 - val_loss: 1.6661 - val_accuracy: 0.2245
# Epoch 9/50
# 55/55 [==============================] - 18s 323ms/step - loss: 1.0979 - accuracy: 0.5057 - val_loss: 1.3699 - val_accuracy: 0.3469
# Epoch 10/50
# 55/55 [==============================] - 16s 285ms/step - loss: 1.0277 - accuracy: 0.5353 - val_loss: 1.2920 - val_accuracy: 0.3878
# Epoch 11/50
# 55/55 [==============================] - 18s 319ms/step - loss: 0.9637 - accuracy: 0.5763 - val_loss: 1.8312 - val_accuracy: 0.2449
# Epoch 12/50
# 55/55 [==============================] - 16s 283ms/step - loss: 0.9726 - accuracy: 0.5672 - val_loss: 1.4317 - val_accuracy: 0.3673
# Epoch 13/50
plt.show()

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt
model = keras.models.load_model("model.keras")

y_pred = model(X_test).numpy().argmax(axis=1)
y_true = y_test
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title("Confusion Matrix")
plt.show()

# %%
y_pred = model(X_train).numpy().argmax(axis=1)
y_true = y_train
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# # Определение углов через вектора

# %%
def get_frames_std(frames):
    # Находит дисперсию точек в каждом кадре
    # frames: (n * 21 * 3)
    mean_pts = frames.mean(axis=1)
    diff = frames - mean_pts[:, None, :]
    norms = np.linalg.norm(diff, axis=2)
    return norms.mean(axis=1)


def filter_frames(frames):
    # Фильтрует кадры по максимальной дисперсии
    max_std = 50
    return frames[get_frames_std(frames) < max_std]
    

def get_points_norm(points: np.ndarray):
    """Находит нормаль плоскости, проходящей через точки"""
    points -= points.mean(axis=0)
    points /= points.std(axis=0)
    if np.any(np.isnan(points)):
        return np.array((0, 0, 0))
    l = LinearRegression(fit_intercept=False).fit(points[:, [0, 1]], points[:, 2])
    norm = np.array((l.coef_[0], l.coef_[1], -1))
    return norm


def vectors_angle(v1, v2):
    """Угол между векторами"""
    v1 = v1 / np.linalg.norm(v1)
    v2 = v2 / np.linalg.norm(v2)
    return np.arccos(np.clip(np.dot(v1, v2), -1.0, 1.0))
    

def get_angle_range(frames: np.ndarray):
    """
    Находит размах угла поворота в градусах по кадрам с 3д точками
    """
    norms = []
    for frame in frames.copy():
        v1 = frame[20] - frame[0]  # вектор до большого пальца
        v2 = frame[20] - frame[16]  # вектор до мизинца
        norms.append(np.cross(v1, v2))

    angle = []
    n0 = norms[0]
    for n in norms:
        angle.append(vectors_angle(n0, n))
        
    angle = np.array(angle)
    min_angle, max_angle = np.quantile(angle, 0.05), np.quantile(angle, 0.95)
    rotation_range = np.rad2deg(max_angle - min_angle)

    # fig, ax = plt.subplots(ncols=2, figsize=(10, 5))
    # ax[0].plot(angle)
    # ax[0].set_xlabel("Номер кадра")
    # ax[0].set_ylabel("Угол поворота, радианы")
    # ax[1].hist(angle, bins=30, orientation='horizontal')
    # plt.show()
    # print(f"Размах вращения: {rotation_range:.2f} градусов")
    
    return rotation_range

# %%
video_angles = []
for i in range(len(filenames)):
    video_angles.append(get_angle_range(X_orig[i]))
video_angles = np.array(video_angles)
# Out:
# /tmp/ipykernel_2826/4005951290.py:30: RuntimeWarning: invalid value encountered in divide
#   v2 = v2 / np.linalg.norm(v2)

# %%
# Предсказания углов для каждого видео
plt.plot(video_angles)

# %%
mean_class_angles = []
for c in range(4):
    ang = video_angles[~np.isnan(video_angles) & (y == c)]
    mean_class_angles.append(ang.mean())

plt.title("Средний угол по классам")
plt.plot(["0", "1", "2", "3"], mean_class_angles, marker="o")
plt.grid()
plt.xlabel("Класс")
plt.ylabel("Средний угол")
# Out:
# Text(0, 0.5, 'Средний угол')

# %% [markdown]
# # Исследование 2

# %% [markdown]
# RNN

# %%
import numpy as np
import pandas as pd
import pathlib
from keras import layers
import keras
import tensorflow as tf
from sklearn.model_selection import train_test_split
import sklearn
import matplotlib.pyplot as plt
import plotly.express as px
from matplotlib.animation import FuncAnimation
from sklearn.linear_model import LinearRegression
import cv2
from IPython.display import HTML

# %%
ds_path = pathlib.Path("points")

# %%
path = list((ds_path / "0").glob("*.npy"))[0]
print(path)

points = np.load(path)
# Out:
# points\0\100_10052025191422_0315b142-246b-11ed-a221-e82aea2c97f4_3dkeypoints.npy

# %% [markdown]
# Загружаем датасет

# %%
ds_path = pathlib.Path("points")
classes = ["0", "1", "2", "3"]

filenames = []
X_orig = []
X = []
y = []

for cls in classes:
    cls_dir = ds_path / cls
    for file_path in cls_dir.glob("*.npy"):
        pts = np.load(file_path)
        X_orig.append(pts)
        filenames.append(file_path.stem)
        # print(pts)
        pts = pts.reshape(-1, 21 * 3)  # Решейпим 21 3д точки в один вектор чисел на 63 элемента
        X.append(pts)
        y.append(int(cls))
y = np.array(y)

# Добавляем паддинг входным данным, чтобы они были одинакового размера
X = tf.keras.utils.pad_sequences(X, padding="post")

# Нормализуем
X = X.astype(float)
X /= X.max()


# Разбиваем на train/test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)
print("Train:", len(X_train))
print("Test:", len(X_test))

print("input_shape =", X.shape[1:])
# Out:
# Train: 445
# Test: 50
# input_shape = (629, 63)

# %%
# Делаем датасет из tf
def augment(x):  # небольшая аугментация со случайным смещением точек
    mul = tf.random.uniform(shape=x.shape, minval=0.99, maxval=1.01, dtype=tf.float64)
    return x * mul

train = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train = train.map(lambda x, y: (augment(x), y))
train = train.shuffle(1000)
train = train.batch(8)

test = tf.data.Dataset.from_tensor_slices((X_test, y_test))
test = test.batch(8)

# %%
# model = keras.Sequential([
#     layers.Masking(mask_value=0.0, input_shape=X.shape[1:]),
#     layers.LSTM(128, input_shape=X.shape[1:], activation='tanh', return_sequences=True),  # Возвращает (629, 128)
#     layers.BatchNormalization(),
#     layers.Dropout(0.1),
    
#     layers.LSTM(128, activation='tanh', return_sequences=False),  # Возвращает вектор 128
#     layers.BatchNormalization(),
#     layers.Dropout(0.1),

#     # LSTM(128, activation='tanh', return_sequences=False),  # Возвращает вектор 128
#     # BatchNormalization(),
#     # Dropout(0.1),
    
#     layers.Dense(32, activation='relu'),
#     layers.Dropout(0.1),
#     layers.Dense(4, activation='softmax'),
# ])

# model.compile(
#     loss='sparse_categorical_crossentropy',
#     optimizer="Adam",
#     metrics=['accuracy'],
# )

# hist = model.fit(
#     train,
#     epochs=50,
#     validation_data=test,
# )

# %% [markdown]
# Строим и обучаем модель

# %%
# from tensorflow import keras
# from tensorflow.keras import layers, regularizers
# from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# model = keras.Sequential([
#     layers.Masking(mask_value=0.0, input_shape=X.shape[1:]),

#     # Bidirectional LSTM для захвата контекста в обе стороны
#     layers.Bidirectional(layers.LSTM(256, return_sequences=True)),
#     layers.BatchNormalization(),
#     layers.Dropout(0.3),

#     layers.Bidirectional(layers.LSTM(128, return_sequences=True)),
#     layers.BatchNormalization(),
#     layers.Dropout(0.3),

#     # Последний LSTM без return_sequences
#     layers.LSTM(64, return_sequences=False),
#     layers.BatchNormalization(),
#     layers.Dropout(0.3),

#     # Мощные Dense-слои с регуляризацией
#     layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
#     layers.BatchNormalization(),
#     layers.Dropout(0.3),

#     layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
#     layers.BatchNormalization(),
#     layers.Dropout(0.3),

#     layers.Dense(4, activation='softmax'),
# ])

# model.compile(
#     loss='sparse_categorical_crossentropy',
#     optimizer=keras.optimizers.Adam(learning_rate=1e-3),
#     metrics=['accuracy'],
# )

# %% [markdown]
# вариант из 1

# %%
model = keras.Sequential([
    layers.Masking(mask_value=0.0, input_shape=X.shape[1:]),
    layers.LSTM(128, input_shape=X.shape[1:], activation='tanh', return_sequences=True),  # Возвращает (629, 128)
    layers.BatchNormalization(),
    layers.Dropout(0.1),
    
    layers.LSTM(128, activation='tanh', return_sequences=False),  # Возвращает вектор 128
    layers.BatchNormalization(),
    layers.Dropout(0.1),

    # LSTM(128, activation='tanh', return_sequences=False),  # Возвращает вектор 128
    # BatchNormalization(),
    # Dropout(0.1),
    
    layers.Dense(32, activation='relu'),
    layers.Dropout(0.1),
    layers.Dense(4, activation='softmax'),
])

model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer="Adam",
    metrics=['accuracy'],
)

hist = model.fit(
    train,
    epochs=50,
    validation_data=test,
)

# %%
from tensorflow import keras
from tensorflow.keras import layers, regularizers

model = keras.Sequential([
    # Маскирование паддингов
    layers.Masking(mask_value=0.0, input_shape=X.shape[1:]),

    # Первый LSTM
    layers.LSTM(128, activation='tanh', return_sequences=True),
    layers.BatchNormalization(),
    layers.Dropout(0.1),

    # Второй LSTM
    layers.LSTM(64, activation='tanh', return_sequences=False),
    layers.BatchNormalization(),
    layers.Dropout(0.1),

    # Более мощная Dense-часть с регуляризацией и нормализацией
    layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.BatchNormalization(),
    layers.Dropout(0.1),

    layers.Dense(32, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.Dropout(0.1),

    layers.Dense(4, activation='softmax'),
])

model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    metrics=['accuracy'],
)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# Сохраняет лучшую модель по val_loss
checkpoint = ModelCheckpoint(
    filepath='models/model_v2.keras',
    monitor='val_loss',    
    save_best_only=True,
    save_weights_only=False,
    verbose=1        
)

# Уменьшает learning rate, если val_loss не улучшается
lr_schedule = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    verbose=1,
    min_lr=1e-6
# Epoch 20/50
# 56/56 [==============================] - ETA: 0s - loss: 1.2187 - accuracy: 0.4854
# Epoch 20: val_loss improved from 1.40569 to 1.32973, saving model to models\model_v2.keras
# 56/56 [==============================] - 38s 660ms/step - loss: 1.2187 - accuracy: 0.4854 - val_loss: 1.3297 - val_accuracy: 0.3400 - lr: 2.5000e-04
# Epoch 21/50
# 56/56 [==============================] - ETA: 0s - loss: 1.1613 - accuracy: 0.5079
# Epoch 21: val_loss did not improve from 1.32973
# 56/56 [==============================] - 38s 649ms/step - loss: 1.1613 - accuracy: 0.5079 - val_loss: 1.3444 - val_accuracy: 0.3400 - lr: 2.5000e-04
# Epoch 22/50
# 56/56 [==============================] - ETA: 0s - loss: 1.1537 - accuracy: 0.5124
# Epoch 22: val_loss did not improve from 1.32973
# 56/56 [==============================] - 39s 666ms/step - loss: 1.1537 - accuracy: 0.5124 - val_loss: 1.5197 - val_accuracy: 0.3000 - lr: 2.5000e-04
# Epoch 23/50
# 56/56 [==============================] - ETA: 0s - loss: 1.1774 - accuracy: 0.5146
# Epoch 23: val_loss did not improve from 1.32973
# 56/56 [==============================] - 38s 648ms/step - loss: 1.1774 - accuracy: 0.5146 - val_loss: 1.5197 - val_accuracy: 0.3600 - lr: 2.5000e-04
# Epoch 24/50
# 56/56 [==============================] - ETA: 0s - loss: 1.1408 - accuracy: 0.5348
# Epoch 24: val_loss did not improve from 1.32973
# 56/56 [==============================] - 37s 634ms/step - loss: 1.1408 - accuracy: 0.5348 - val_loss: 1.3700 - val_accuracy: 0.3800 - lr: 2.5000e-04
# Epoch 25/50
# 56/56 [==============================] - ETA: 0s - loss: 1.0695 - accuracy: 0.5573
# Epoch 25: val_loss did not improve from 1.32973
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 56/56 [==============================] - 37s 630ms/step - loss: 1.0695 - accuracy: 0.5573 - val_loss: 1.3567 - val_accuracy: 0.4400 - lr: 2.5000e-04
# Epoch 26/50
# 56/56 [==============================] - ETA: 0s - loss: 1.0898 - accuracy: 0.5708
# Epoch 26: val_loss did not improve from 1.32973
# 56/56 [==============================] - 37s 637ms/step - loss: 1.0898 - accuracy: 0.5708 - val_loss: 1.3696 - val_accuracy: 0.4800 - lr: 1.2500e-04
# Epoch 27/50
# 27/56 [=============>................] - ETA: 17s - loss: 1.0354 - accuracy: 0.6157

# %%
# model.save("model.keras")

# %%
plt.plot(hist.history["accuracy"], marker="o")
plt.plot(hist.history["val_accuracy"], marker="o")
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.grid()
plt.legend(["train", "valid"])
plt.show()

# %% [markdown]
# # Проверка

# %%
# Проверка
# Делаем датасет из tf
def augment(x):  # небольшая аугментация со случайным смещением точек
    mul = tf.random.uniform(shape=x.shape, minval=0.99, maxval=1.01, dtype=tf.float64)
    return x * mul

train = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train = train.map(lambda x, y: (augment(x), y))
train = train.shuffle(1000)
train = train.batch(8)

test = tf.data.Dataset.from_tensor_slices((X_test, y_test))
test = test.batch(8)

# %%
# Проверка
model = keras.Sequential([
    layers.Masking(mask_value=0.0, input_shape=X.shape[1:]),
    layers.LSTM(128, input_shape=X.shape[1:], activation='tanh', return_sequences=True),  # Возвращает (629, 128)
    layers.BatchNormalization(),
    layers.Dropout(0.1),
    
    layers.LSTM(128, activation='tanh', return_sequences=False),  # Возвращает вектор 128
    layers.BatchNormalization(),
    layers.Dropout(0.1),

    # LSTM(128, activation='tanh', return_sequences=False),  # Возвращает вектор 128
    # BatchNormalization(),
    # Dropout(0.1),
    
    layers.Dense(32, activation='relu'),
    layers.Dropout(0.1),
    layers.Dense(4, activation='softmax'),
])

model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer="Adam",
    metrics=['accuracy'],
)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# Сохраняет лучшую модель по val_loss
checkpoint = ModelCheckpoint(
    filepath='models/model_v3.keras',
    monitor='val_loss',    
    save_best_only=True,
    save_weights_only=False,
    verbose=1        
)

# Уменьшает learning rate, если val_loss не улучшается
lr_schedule = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.9,
    patience=5,
    verbose=1,
    min_lr=1e-6
)

# %%
hist = model.fit(
    train,
    epochs=50,
    validation_data=test,
    callbacks=[checkpoint, lr_schedule],
)
# Out:
# Epoch 1/50
# 56/56 [==============================] - ETA: 0s - loss: 1.5849 - accuracy: 0.3191
# Epoch 1: val_loss improved from inf to 1.35506, saving model to models\model_v3.keras
# 56/56 [==============================] - 62s 845ms/step - loss: 1.5849 - accuracy: 0.3191 - val_loss: 1.3551 - val_accuracy: 0.3800 - lr: 0.0010
# Epoch 2/50
# 56/56 [==============================] - ETA: 0s - loss: 1.3827 - accuracy: 0.3910
# Epoch 2: val_loss improved from 1.35506 to 1.33489, saving model to models\model_v3.keras
# 56/56 [==============================] - 41s 713ms/step - loss: 1.3827 - accuracy: 0.3910 - val_loss: 1.3349 - val_accuracy: 0.3800 - lr: 0.0010
# Epoch 3/50
# 56/56 [==============================] - ETA: 0s - loss: 1.3250 - accuracy: 0.3685
# Epoch 3: val_loss did not improve from 1.33489
# 56/56 [==============================] - 45s 778ms/step - loss: 1.3250 - accuracy: 0.3685 - val_loss: 1.3527 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 4/50
# 56/56 [==============================] - ETA: 0s - loss: 1.2932 - accuracy: 0.4157
# Epoch 4: val_loss did not improve from 1.33489
# 56/56 [==============================] - 44s 765ms/step - loss: 1.2932 - accuracy: 0.4157 - val_loss: 1.5054 - val_accuracy: 0.2600 - lr: 0.0010
# Epoch 5/50
# 56/56 [==============================] - ETA: 0s - loss: 1.2200 - accuracy: 0.4382
# Epoch 5: val_loss did not improve from 1.33489
# 56/56 [==============================] - 44s 761ms/step - loss: 1.2200 - accuracy: 0.4382 - val_loss: 1.4837 - val_accuracy: 0.3200 - lr: 0.0010
# Epoch 6/50
# 56/56 [==============================] - ETA: 0s - loss: 1.2044 - accuracy: 0.4404
# Epoch 6: val_loss did not improve from 1.33489
# Epoch 44: val_loss did not improve from 1.11435
# 56/56 [==============================] - 35s 596ms/step - loss: 0.3476 - accuracy: 0.8584 - val_loss: 1.5972 - val_accuracy: 0.5400 - lr: 4.7830e-04
# Epoch 45/50
# 56/56 [==============================] - ETA: 0s - loss: 0.3668 - accuracy: 0.8539
# Epoch 45: val_loss did not improve from 1.11435
# 56/56 [==============================] - 35s 606ms/step - loss: 0.3668 - accuracy: 0.8539 - val_loss: 1.6916 - val_accuracy: 0.5400 - lr: 4.7830e-04
# Epoch 46/50
# 56/56 [==============================] - ETA: 0s - loss: 0.3526 - accuracy: 0.8629
# Epoch 46: val_loss did not improve from 1.11435
# 56/56 [==============================] - 35s 599ms/step - loss: 0.3526 - accuracy: 0.8629 - val_loss: 1.5622 - val_accuracy: 0.6000 - lr: 4.7830e-04
# Epoch 47/50
# 56/56 [==============================] - ETA: 0s - loss: 0.3773 - accuracy: 0.8382
# Epoch 47: val_loss did not improve from 1.11435
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.0004304672533180565.
# 56/56 [==============================] - 35s 605ms/step - loss: 0.3773 - accuracy: 0.8382 - val_loss: 1.4668 - val_accuracy: 0.5200 - lr: 4.7830e-04
# Epoch 48/50
# 56/56 [==============================] - ETA: 0s - loss: 0.3537 - accuracy: 0.8539
# Epoch 48: val_loss did not improve from 1.11435
# 56/56 [==============================] - 35s 602ms/step - loss: 0.3537 - accuracy: 0.8539 - val_loss: 1.6819 - val_accuracy: 0.5600 - lr: 4.3047e-04
# Epoch 49/50
# 56/56 [==============================] - ETA: 0s - loss: 0.3635 - accuracy: 0.8742
# Epoch 49: val_loss did not improve from 1.11435
# 56/56 [==============================] - 35s 601ms/step - loss: 0.3635 - accuracy: 0.8742 - val_loss: 1.2985 - val_accuracy: 0.6200 - lr: 4.3047e-04
# Epoch 50/50
# 56/56 [==============================] - ETA: 0s - loss: 0.3222 - accuracy: 0.8742
# Epoch 50: val_loss did not improve from 1.11435
# 56/56 [==============================] - 35s 596ms/step - loss: 0.3222 - accuracy: 0.8742 - val_loss: 1.1750 - val_accuracy: 0.6800 - lr: 4.3047e-04

# %%
plt.plot(hist.history["accuracy"], marker="o")
plt.plot(hist.history["val_accuracy"], marker="o")
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.grid()
plt.legend(["train", "valid"])
plt.show()

# %% [markdown]
# немного дообучим модель

# %%
# from tensorflow.keras.models import load_model

# # Загрузка модели
# model = load_model('models/best_model.keras')

# # Изменение learning rate (например, 1e-4)
# keras.backend.set_value(model.optimizer.learning_rate, 1e-4)

# # Дообучение
# model.fit(
#     train,
#     validation_data=test,
#     epochs=5,
#     callbacks=[checkpoint, lr_schedule],  # или другие
# )

# %%
keras.backend.set_value(model.optimizer.learning_rate, 1e-4)

# %%
hist2 = model.fit(
    train,
    validation_data=test,
    epochs=5,
    callbacks=[checkpoint, lr_schedule],
)
# Out:
# Epoch 1/5
# 56/56 [==============================] - ETA: 0s - loss: 0.2944 - accuracy: 0.8809
# Epoch 1: val_loss did not improve from 1.11435
# 56/56 [==============================] - 34s 595ms/step - loss: 0.2944 - accuracy: 0.8809 - val_loss: 1.3256 - val_accuracy: 0.6800 - lr: 1.0000e-04
# Epoch 2/5
# 56/56 [==============================] - ETA: 0s - loss: 0.3177 - accuracy: 0.8607
# Epoch 2: val_loss did not improve from 1.11435
# 56/56 [==============================] - 35s 609ms/step - loss: 0.3177 - accuracy: 0.8607 - val_loss: 1.3486 - val_accuracy: 0.7000 - lr: 1.0000e-04
# Epoch 3/5
# 56/56 [==============================] - ETA: 0s - loss: 0.3047 - accuracy: 0.8652
# Epoch 3: val_loss did not improve from 1.11435
# 56/56 [==============================] - 35s 596ms/step - loss: 0.3047 - accuracy: 0.8652 - val_loss: 1.3838 - val_accuracy: 0.7200 - lr: 1.0000e-04
# Epoch 4/5
# 56/56 [==============================] - ETA: 0s - loss: 0.3214 - accuracy: 0.8719
# Epoch 4: val_loss did not improve from 1.11435
# 56/56 [==============================] - 35s 601ms/step - loss: 0.3214 - accuracy: 0.8719 - val_loss: 1.4158 - val_accuracy: 0.7000 - lr: 1.0000e-04
# Epoch 5/5
# 56/56 [==============================] - ETA: 0s - loss: 0.3357 - accuracy: 0.8539
# Epoch 5: val_loss did not improve from 1.11435
# 56/56 [==============================] - 35s 599ms/step - loss: 0.3357 - accuracy: 0.8539 - val_loss: 1.3528 - val_accuracy: 0.6800 - lr: 1.0000e-04

# %%
plt.plot(hist2.history["accuracy"], marker="o")
plt.plot(hist2.history["val_accuracy"], marker="o")
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.grid()
plt.legend(["train", "valid"])
plt.show()

# %%
model.save("models/model_v3.keras")

# %% [markdown]
# ещё немного

# %%
keras.backend.set_value(model.optimizer.learning_rate, 0.00009)

# %%
hist2 = model.fit(
    train,
    validation_data=test,
    epochs=10,
    callbacks=[checkpoint, lr_schedule],
)
# Out:
# Epoch 1/10
# 56/56 [==============================] - ETA: 0s - loss: 0.2838 - accuracy: 0.8876
# Epoch 1: val_loss did not improve from 1.11435
# 56/56 [==============================] - 36s 619ms/step - loss: 0.2838 - accuracy: 0.8876 - val_loss: 1.3402 - val_accuracy: 0.7000 - lr: 9.0000e-05
# Epoch 2/10
# 56/56 [==============================] - ETA: 0s - loss: 0.2470 - accuracy: 0.9056
# Epoch 2: val_loss did not improve from 1.11435
# 56/56 [==============================] - 35s 609ms/step - loss: 0.2470 - accuracy: 0.9056 - val_loss: 1.2699 - val_accuracy: 0.7000 - lr: 9.0000e-05
# Epoch 3/10
# 56/56 [==============================] - ETA: 0s - loss: 0.2564 - accuracy: 0.8899
# Epoch 3: val_loss did not improve from 1.11435
# 56/56 [==============================] - 36s 617ms/step - loss: 0.2564 - accuracy: 0.8899 - val_loss: 1.3389 - val_accuracy: 0.6800 - lr: 9.0000e-05
# Epoch 4/10
# 56/56 [==============================] - ETA: 0s - loss: 0.2835 - accuracy: 0.9011
# Epoch 4: val_loss did not improve from 1.11435
# 56/56 [==============================] - 36s 615ms/step - loss: 0.2835 - accuracy: 0.9011 - val_loss: 1.4716 - val_accuracy: 0.6400 - lr: 9.0000e-05
# Epoch 5/10
# 56/56 [==============================] - ETA: 0s - loss: 0.2354 - accuracy: 0.9258
# Epoch 5: val_loss did not improve from 1.11435
# 56/56 [==============================] - 36s 630ms/step - loss: 0.2354 - accuracy: 0.9258 - val_loss: 1.4797 - val_accuracy: 0.6400 - lr: 9.0000e-05
# Epoch 6/10
# 56/56 [==============================] - ETA: 0s - loss: 0.2170 - accuracy: 0.9258
# Epoch 6: val_loss did not improve from 1.11435
# 56/56 [==============================] - 36s 626ms/step - loss: 0.2170 - accuracy: 0.9258 - val_loss: 1.4642 - val_accuracy: 0.6400 - lr: 9.0000e-05
# Epoch 7/10
# 56/56 [==============================] - ETA: 0s - loss: 0.2581 - accuracy: 0.8854
# Epoch 7: val_loss did not improve from 1.11435
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 8.100000122794882e-05.
# 56/56 [==============================] - 35s 610ms/step - loss: 0.2581 - accuracy: 0.8854 - val_loss: 1.2854 - val_accuracy: 0.7200 - lr: 9.0000e-05
# Epoch 8/10
# 56/56 [==============================] - ETA: 0s - loss: 0.2288 - accuracy: 0.9146
# Epoch 8: val_loss did not improve from 1.11435
# 56/56 [==============================] - 35s 607ms/step - loss: 0.2288 - accuracy: 0.9146 - val_loss: 1.2930 - val_accuracy: 0.7400 - lr: 8.1000e-05
# Epoch 9/10
# 56/56 [==============================] - ETA: 0s - loss: 0.2344 - accuracy: 0.9079
# Epoch 9: val_loss did not improve from 1.11435
# 56/56 [==============================] - 35s 609ms/step - loss: 0.2344 - accuracy: 0.9079 - val_loss: 1.3200 - val_accuracy: 0.7400 - lr: 8.1000e-05
# Epoch 10/10
# 56/56 [==============================] - ETA: 0s - loss: 0.2520 - accuracy: 0.9056
# Epoch 10: val_loss did not improve from 1.11435
# 56/56 [==============================] - 36s 624ms/step - loss: 0.2520 - accuracy: 0.9056 - val_loss: 1.2635 - val_accuracy: 0.7000 - lr: 8.1000e-05

# %%
model.save("models/model_v3.keras")

# %%
plt.plot(hist2.history["accuracy"], marker="o")
plt.plot(hist2.history["val_accuracy"], marker="o")
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.grid()
plt.legend(["train", "valid"])
plt.show()

# %%
keras.backend.set_value(model.optimizer.learning_rate, 0.00005)

# %%
hist3 = model.fit(
    train,
    validation_data=test,
    epochs=15,
    callbacks=[checkpoint, lr_schedule],
)
# Out:
# Epoch 1/15
# 56/56 [==============================] - ETA: 0s - loss: 0.2776 - accuracy: 0.8966
# Epoch 1: val_loss did not improve from 1.11435
# 56/56 [==============================] - 36s 622ms/step - loss: 0.2776 - accuracy: 0.8966 - val_loss: 1.3894 - val_accuracy: 0.6400 - lr: 5.0000e-05
# Epoch 2/15
# 56/56 [==============================] - ETA: 0s - loss: 0.2355 - accuracy: 0.9034
# Epoch 2: val_loss did not improve from 1.11435
# 56/56 [==============================] - 37s 633ms/step - loss: 0.2355 - accuracy: 0.9034 - val_loss: 1.2830 - val_accuracy: 0.7200 - lr: 5.0000e-05
# Epoch 12: ReduceLROnPlateau reducing learning rate to 4.050000061397441e-05.
# 56/56 [==============================] - 36s 628ms/step - loss: 0.2137 - accuracy: 0.9056 - val_loss: 1.4461 - val_accuracy: 0.6800 - lr: 4.5000e-05
# Epoch 13/15
# 56/56 [==============================] - ETA: 0s - loss: 0.2166 - accuracy: 0.9011
# Epoch 13: val_loss did not improve from 1.11435
# 56/56 [==============================] - 36s 624ms/step - loss: 0.2166 - accuracy: 0.9011 - val_loss: 1.3881 - val_accuracy: 0.6800 - lr: 4.0500e-05
# Epoch 14/15
# 56/56 [==============================] - ETA: 0s - loss: 0.2217 - accuracy: 0.9169
# Epoch 14: val_loss did not improve from 1.11435
# 56/56 [==============================] - 35s 611ms/step - loss: 0.2217 - accuracy: 0.9169 - val_loss: 1.3772 - val_accuracy: 0.6800 - lr: 4.0500e-05
# Epoch 15/15
# 56/56 [==============================] - ETA: 0s - loss: 0.1915 - accuracy: 0.9281
# Epoch 15: val_loss did not improve from 1.11435
# 56/56 [==============================] - 35s 606ms/step - loss: 0.1915 - accuracy: 0.9281 - val_loss: 1.3910 - val_accuracy: 0.7000 - lr: 4.0500e-05

# %%
keras.backend.set_value(model.optimizer.learning_rate, 0.000001)

# %%
hist4 = model.fit(
    train,
    validation_data=test,
    epochs=5,
    callbacks=[checkpoint, lr_schedule],
)
# Out:
# Epoch 1/5
# 56/56 [==============================] - ETA: 0s - loss: 0.2389 - accuracy: 0.9079
# Epoch 1: val_loss did not improve from 1.11435
# 56/56 [==============================] - 36s 614ms/step - loss: 0.2389 - accuracy: 0.9079 - val_loss: 1.3998 - val_accuracy: 0.7000 - lr: 1.0000e-06
# Epoch 2/5
# 56/56 [==============================] - ETA: 0s - loss: 0.2225 - accuracy: 0.9079
# Epoch 2: val_loss did not improve from 1.11435
# 56/56 [==============================] - 35s 607ms/step - loss: 0.2225 - accuracy: 0.9079 - val_loss: 1.3987 - val_accuracy: 0.7000 - lr: 1.0000e-06
# Epoch 3/5
# 56/56 [==============================] - ETA: 0s - loss: 0.2192 - accuracy: 0.9124
# Epoch 3: val_loss did not improve from 1.11435
# 56/56 [==============================] - 35s 607ms/step - loss: 0.2192 - accuracy: 0.9124 - val_loss: 1.4009 - val_accuracy: 0.7200 - lr: 1.0000e-06
# Epoch 4/5
# 56/56 [==============================] - ETA: 0s - loss: 0.2218 - accuracy: 0.9079
# Epoch 4: val_loss did not improve from 1.11435
# 56/56 [==============================] - 35s 607ms/step - loss: 0.2218 - accuracy: 0.9079 - val_loss: 1.4042 - val_accuracy: 0.7200 - lr: 1.0000e-06
# Epoch 5/5
# 56/56 [==============================] - ETA: 0s - loss: 0.2192 - accuracy: 0.9011
# Epoch 5: val_loss did not improve from 1.11435
# 56/56 [==============================] - 35s 596ms/step - loss: 0.2192 - accuracy: 0.9011 - val_loss: 1.3983 - val_accuracy: 0.7200 - lr: 1.0000e-06

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt
# model = keras.models.load_model("model.keras")

y_pred = model(X_test).numpy().argmax(axis=1)
y_true = y_test
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title("Confusion Matrix")
plt.show()

# %%
y_pred = model(X_train).numpy().argmax(axis=1)
y_true = y_train
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# # Определение углов через вектора

# %%
def get_frames_std(frames):
    # Находит дисперсию точек в каждом кадре
    # frames: (n * 21 * 3)
    mean_pts = frames.mean(axis=1)
    diff = frames - mean_pts[:, None, :]
    norms = np.linalg.norm(diff, axis=2)
    return norms.mean(axis=1)


def filter_frames(frames):
    # Фильтрует кадры по максимальной дисперсии
    max_std = 50
    return frames[get_frames_std(frames) < max_std]
    

def get_points_norm(points: np.ndarray):
    """Находит нормаль плоскости, проходящей через точки"""
    points -= points.mean(axis=0)
    points /= points.std(axis=0)
    if np.any(np.isnan(points)):
        return np.array((0, 0, 0))
    l = LinearRegression(fit_intercept=False).fit(points[:, [0, 1]], points[:, 2])
    norm = np.array((l.coef_[0], l.coef_[1], -1))
    return norm


def vectors_angle(v1, v2):
    """Угол между векторами"""
    v1 = v1 / np.linalg.norm(v1)
    v2 = v2 / np.linalg.norm(v2)
    return np.arccos(np.clip(np.dot(v1, v2), -1.0, 1.0))
    

def get_angle_range(frames: np.ndarray):
    """
    Находит размах угла поворота в градусах по кадрам с 3д точками
    """
    norms = []
    for frame in frames.copy():
        v1 = frame[20] - frame[0]  # вектор до большого пальца
        v2 = frame[20] - frame[16]  # вектор до мизинца
        norms.append(np.cross(v1, v2))

    angle = []
    n0 = norms[0]
    for n in norms:
        angle.append(vectors_angle(n0, n))
        
    angle = np.array(angle)
    min_angle, max_angle = np.quantile(angle, 0.05), np.quantile(angle, 0.95)
    rotation_range = np.rad2deg(max_angle - min_angle)

    # fig, ax = plt.subplots(ncols=2, figsize=(10, 5))
    # ax[0].plot(angle)
    # ax[0].set_xlabel("Номер кадра")
    # ax[0].set_ylabel("Угол поворота, радианы")
    # ax[1].hist(angle, bins=30, orientation='horizontal')
    # plt.show()
    # print(f"Размах вращения: {rotation_range:.2f} градусов")
    
    return rotation_range

# %%
video_angles = []
for i in range(len(filenames)):
    video_angles.append(get_angle_range(X_orig[i]))
video_angles = np.array(video_angles)
# Out:
# C:\Users\maxim\AppData\Local\Temp\ipykernel_8484\4005951290.py:30: RuntimeWarning: invalid value encountered in divide
#   v2 = v2 / np.linalg.norm(v2)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 12))
plt.plot(video_angles, linestyle='None', marker='o')
plt.title("Предсказанные углы для видео")
plt.xlabel("Кадр")
plt.ylabel("Угол (градусы)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
mean_class_angles = []
for c in range(4):
    ang = video_angles[~np.isnan(video_angles) & (y == c)]
    mean_class_angles.append(ang.mean())

plt.title("Средний угол по классам")
plt.plot(["0", "1", "2", "3"], mean_class_angles, marker="o")
plt.grid()
plt.xlabel("Класс")
plt.ylabel("Средний угол")
# Out:
# Text(0, 0.5, 'Средний угол')
