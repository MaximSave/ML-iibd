# %%
import os
import pickle
import tarfile
import datetime
import numpy as np
import urllib.request
import sklearn.metrics
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
              tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# %%
# %load_ext tensorboard

# %%
HISTORY_DIR = './history'
os.makedirs(HISTORY_DIR, exist_ok=True)

# %%
def get_data():
    if not os.path.exists('cifar-10-batches-py/'):
        urllib.request.urlretrieve('https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz', 'cifar-10-python.tar.gz')
        file = tarfile.open('cifar-10-python.tar.gz', 'r:gz')
        file.extractall()
        
    X, y = [], []
    for i in range(1, 6):
        d = pickle.load(open(os.path.join('cifar-10-batches-py', f'data_batch_{i}'), 'rb'), encoding='bytes')
        X.append(d[b'data'])
        y.append(d[b'labels'])
        
    d = pickle.load(open(os.path.join('cifar-10-batches-py', 'test_batch'), 'rb'), encoding='bytes')
        
    return (
        np.concatenate(X, axis=0).reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1),
        np.concatenate(y, axis=0),
        pickle.load(open('cifar-10-batches-py/batches.meta', 'rb'))['label_names'],
        np.array(d[b'data']).reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1),
        np.array(d[b'labels'])
    )

# %%
def plot_confusion_matrix(model: tf.keras.models.Model, X: np.ndarray, y: np.ndarray, labels: list[str], batch_size: int = 8, **kwargs):
    y_pred = model.predict(X, verbose=False, batch_size=batch_size).argmax(axis=-1)
    sklearn.metrics.ConfusionMatrixDisplay.from_predictions(
        y,
        y_pred,
        display_labels=labels,
        xticks_rotation='vertical',
        **kwargs
    )

# %%
X, y, labels, X_test, y_test = get_data()

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau

model = models.Sequential([
    layers.Input(shape=(32, 32, 3)),

    layers.Conv2D(64, (3, 3), padding='same'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.Conv2D(64, (3, 3), padding='same'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.3),

    layers.Conv2D(128, (3, 3), padding='same'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.Conv2D(128, (3, 3), padding='same'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.4),

    layers.Conv2D(256, (3, 3), padding='same'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.Conv2D(256, (3, 3), padding='same'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.4),

    layers.Flatten(),
    layers.Dense(512),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.Dropout(0.5),

    layers.Dense(10, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 32, 32, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 32, 32, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 32, 32, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 32, 32, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 16, 16, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 16, 16, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_2 (Activation)            │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 16, 16, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 16, 16, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_3 (Activation)            │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 8, 8, 256)           │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 8, 8, 256)           │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_4 (Activation)            │ (None, 8, 8, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 8, 8, 256)           │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 8, 8, 256)           │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_5 (Activation)            │ (None, 8, 8, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 4, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 4, 4, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 4096)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │       2,097,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_6 (Activation)            │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           5,130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,253,834 (12.41 MB)
#  Trainable params: 3,251,018 (12.40 MB)
#  Non-trainable params: 2,816 (11.00 KB)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
logdir = os.path.join(HISTORY_DIR, datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))

# %%
# %tensorboard --logdir $logdir
# Out:
#       <iframe id="tensorboard-frame-3e301f1f7261a2f6" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-3e301f1f7261a2f6");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath=os.path.join(logdir, 'model.keras'),
        save_best_only=True
    ),
    tf.keras.callbacks.TensorBoard(
        log_dir=os.path.join(logdir, 'logs')
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_accuracy',
        factor=0.5,
        patience=5,
        verbose=1
    )
]

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
)
datagen.fit(X)

# %%
# !dir /b
# Out:
# .ipynb_checkpoints
# cifar-10-batches-py
# cifar-10-python.tar.gz
# cifar_10.ipynb
# history
# Text Document.txt

# %%
history = model.fit(
    datagen.flow(X, y, batch_size=64),
    epochs=100,
    validation_data=(X_test, y_test),
    callbacks=callbacks
)
# Out:
# C:\Users\maxim\anaconda3\envs\neural-networks\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 126s 154ms/step - accuracy: 0.3628 - loss: 1.8762 - val_accuracy: 0.5056 - val_loss: 1.3888 - learning_rate: 0.0010
# Epoch 2/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 119s 152ms/step - accuracy: 0.5905 - loss: 1.1446 - val_accuracy: 0.4185 - val_loss: 1.9886 - learning_rate: 0.0010
# Epoch 3/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 121s 155ms/step - accuracy: 0.6671 - loss: 0.9426 - val_accuracy: 0.7258 - val_loss: 0.8095 - learning_rate: 0.0010
# Epoch 4/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 126s 161ms/step - accuracy: 0.7066 - loss: 0.8364 - val_accuracy: 0.7512 - val_loss: 0.7213 - learning_rate: 0.0010
# Epoch 5/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 124s 158ms/step - accuracy: 0.7285 - loss: 0.7708 - val_accuracy: 0.7086 - val_loss: 0.8861 - learning_rate: 0.0010
# Epoch 6/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 125s 160ms/step - accuracy: 0.7497 - loss: 0.7258 - val_accuracy: 0.7754 - val_loss: 0.6453 - learning_rate: 0.0010
# Epoch 7/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 126s 161ms/step - accuracy: 0.7660 - loss: 0.6762 - val_accuracy: 0.7879 - val_loss: 0.6216 - learning_rate: 0.0010
# Epoch 8/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 129s 165ms/step - accuracy: 0.7782 - loss: 0.6392 - val_accuracy: 0.7659 - val_loss: 0.6949 - learning_rate: 0.0010
# Epoch 9/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 133s 170ms/step - accuracy: 0.7860 - loss: 0.6126 - val_accuracy: 0.7207 - val_loss: 0.8510 - learning_rate: 0.0010
# Epoch 10/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 131s 168ms/step - accuracy: 0.7988 - loss: 0.5862 - val_accuracy: 0.8307 - val_loss: 0.5013 - learning_rate: 0.0010
# Epoch 11/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 123s 157ms/step - accuracy: 0.8029 - loss: 0.5795 - val_accuracy: 0.7559 - val_loss: 0.7422 - learning_rate: 0.0010
# Epoch 12/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 123s 157ms/step - accuracy: 0.8192 - loss: 0.5249 - val_accuracy: 0.8381 - val_loss: 0.4771 - learning_rate: 0.0010
# Epoch 13/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 124s 158ms/step - accuracy: 0.8185 - loss: 0.5282 - val_accuracy: 0.8290 - val_loss: 0.5077 - learning_rate: 0.0010
# Epoch 14/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 125s 159ms/step - accuracy: 0.8286 - loss: 0.4968 - val_accuracy: 0.8291 - val_loss: 0.5108 - learning_rate: 0.0010
# Epoch 15/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 124s 158ms/step - accuracy: 0.8330 - loss: 0.4839 - val_accuracy: 0.8362 - val_loss: 0.4761 - learning_rate: 0.0010
# Epoch 16/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 128s 164ms/step - accuracy: 0.8373 - loss: 0.4685 - val_accuracy: 0.8459 - val_loss: 0.4529 - learning_rate: 0.0010
# Epoch 17/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 130s 167ms/step - accuracy: 0.8420 - loss: 0.4585 - val_accuracy: 0.8511 - val_loss: 0.4339 - learning_rate: 0.0010
# Epoch 18/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 130s 166ms/step - accuracy: 0.8453 - loss: 0.4417 - val_accuracy: 0.8401 - val_loss: 0.4610 - learning_rate: 0.0010
# Epoch 19/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 126s 161ms/step - accuracy: 0.8513 - loss: 0.4280 - val_accuracy: 0.8513 - val_loss: 0.4409 - learning_rate: 0.0010
# Epoch 20/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 125s 159ms/step - accuracy: 0.8537 - loss: 0.4204 - val_accuracy: 0.8597 - val_loss: 0.4147 - learning_rate: 0.0010
# Epoch 21/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 124s 159ms/step - accuracy: 0.8574 - loss: 0.4107 - val_accuracy: 0.8581 - val_loss: 0.4255 - learning_rate: 0.0010
# Epoch 22/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 125s 160ms/step - accuracy: 0.8582 - loss: 0.4107 - val_accuracy: 0.8532 - val_loss: 0.4548 - learning_rate: 0.0010
# Epoch 23/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 126s 161ms/step - accuracy: 0.8632 - loss: 0.3942 - val_accuracy: 0.8664 - val_loss: 0.4106 - learning_rate: 0.0010
# Epoch 24/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 130s 166ms/step - accuracy: 0.8666 - loss: 0.3881 - val_accuracy: 0.8492 - val_loss: 0.4698 - learning_rate: 0.0010
# Epoch 25/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 129s 165ms/step - accuracy: 0.8682 - loss: 0.3780 - val_accuracy: 0.8499 - val_loss: 0.4568 - learning_rate: 0.0010
# Epoch 26/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 134s 171ms/step - accuracy: 0.8685 - loss: 0.3740 - val_accuracy: 0.8815 - val_loss: 0.3495 - learning_rate: 0.0010
# Epoch 27/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 133s 170ms/step - accuracy: 0.8744 - loss: 0.3655 - val_accuracy: 0.8458 - val_loss: 0.4701 - learning_rate: 0.0010
# Epoch 28/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 134s 172ms/step - accuracy: 0.8746 - loss: 0.3626 - val_accuracy: 0.8701 - val_loss: 0.4030 - learning_rate: 0.0010
# Epoch 29/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 132s 169ms/step - accuracy: 0.8772 - loss: 0.3553 - val_accuracy: 0.8584 - val_loss: 0.4540 - learning_rate: 0.0010
# Epoch 30/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 131s 168ms/step - accuracy: 0.8818 - loss: 0.3424 - val_accuracy: 0.8620 - val_loss: 0.4315 - learning_rate: 0.0010
# Epoch 31/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 136s 174ms/step - accuracy: 0.8800 - loss: 0.3415 - val_accuracy: 0.8822 - val_loss: 0.3515 - learning_rate: 0.0010
# Epoch 32/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 134s 171ms/step - accuracy: 0.8845 - loss: 0.3296 - val_accuracy: 0.8616 - val_loss: 0.4264 - learning_rate: 0.0010
# Epoch 33/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 136s 174ms/step - accuracy: 0.8878 - loss: 0.3254 - val_accuracy: 0.8448 - val_loss: 0.5080 - learning_rate: 0.0010
# Epoch 34/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 134s 172ms/step - accuracy: 0.8860 - loss: 0.3273 - val_accuracy: 0.8786 - val_loss: 0.3708 - learning_rate: 0.0010
# Epoch 35/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 134s 171ms/step - accuracy: 0.8841 - loss: 0.3308 - val_accuracy: 0.8892 - val_loss: 0.3410 - learning_rate: 0.0010
# Epoch 36/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 139s 177ms/step - accuracy: 0.8886 - loss: 0.3183 - val_accuracy: 0.8645 - val_loss: 0.4268 - learning_rate: 0.0010
# Epoch 37/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 127s 163ms/step - accuracy: 0.8902 - loss: 0.3160 - val_accuracy: 0.8963 - val_loss: 0.3232 - learning_rate: 0.0010
# Epoch 38/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 128s 164ms/step - accuracy: 0.8908 - loss: 0.3136 - val_accuracy: 0.8863 - val_loss: 0.3565 - learning_rate: 0.0010
# Epoch 39/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 124s 159ms/step - accuracy: 0.8941 - loss: 0.3061 - val_accuracy: 0.8738 - val_loss: 0.3998 - learning_rate: 0.0010
# Epoch 40/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 125s 160ms/step - accuracy: 0.8936 - loss: 0.3028 - val_accuracy: 0.8835 - val_loss: 0.3519 - learning_rate: 0.0010
# Epoch 41/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 126s 162ms/step - accuracy: 0.8966 - loss: 0.3004 - val_accuracy: 0.8793 - val_loss: 0.3963 - learning_rate: 0.0010
# Epoch 42/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.8965 - loss: 0.2962
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 127s 162ms/step - accuracy: 0.8965 - loss: 0.2962 - val_accuracy: 0.8912 - val_loss: 0.3325 - learning_rate: 0.0010
# Epoch 43/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 123s 158ms/step - accuracy: 0.9013 - loss: 0.2829 - val_accuracy: 0.8778 - val_loss: 0.3885 - learning_rate: 5.0000e-04
# Epoch 44/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 126s 161ms/step - accuracy: 0.9101 - loss: 0.2555 - val_accuracy: 0.9028 - val_loss: 0.3056 - learning_rate: 5.0000e-04
# Epoch 45/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 127s 162ms/step - accuracy: 0.9081 - loss: 0.2605 - val_accuracy: 0.8982 - val_loss: 0.3210 - learning_rate: 5.0000e-04
# Epoch 46/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 127s 163ms/step - accuracy: 0.9092 - loss: 0.2608 - val_accuracy: 0.8886 - val_loss: 0.3529 - learning_rate: 5.0000e-04
# Epoch 47/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 126s 161ms/step - accuracy: 0.9138 - loss: 0.2494 - val_accuracy: 0.8859 - val_loss: 0.3513 - learning_rate: 5.0000e-04
# Epoch 48/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 127s 162ms/step - accuracy: 0.9169 - loss: 0.2417 - val_accuracy: 0.9037 - val_loss: 0.2998 - learning_rate: 5.0000e-04
# Epoch 49/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 125s 160ms/step - accuracy: 0.9145 - loss: 0.2438 - val_accuracy: 0.8939 - val_loss: 0.3405 - learning_rate: 5.0000e-04
# Epoch 50/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 127s 162ms/step - accuracy: 0.9176 - loss: 0.2341 - val_accuracy: 0.8894 - val_loss: 0.3618 - learning_rate: 5.0000e-04
# Epoch 51/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 127s 162ms/step - accuracy: 0.9153 - loss: 0.2385 - val_accuracy: 0.9056 - val_loss: 0.3015 - learning_rate: 5.0000e-04
# Epoch 52/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 127s 162ms/step - accuracy: 0.9183 - loss: 0.2341 - val_accuracy: 0.9038 - val_loss: 0.3202 - learning_rate: 5.0000e-04
# Epoch 53/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 129s 165ms/step - accuracy: 0.9162 - loss: 0.2384 - val_accuracy: 0.8978 - val_loss: 0.3289 - learning_rate: 5.0000e-04
# Epoch 54/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 129s 164ms/step - accuracy: 0.9176 - loss: 0.2330 - val_accuracy: 0.9012 - val_loss: 0.3234 - learning_rate: 5.0000e-04
# Epoch 55/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 125s 160ms/step - accuracy: 0.9188 - loss: 0.2354 - val_accuracy: 0.9064 - val_loss: 0.3035 - learning_rate: 5.0000e-04
# Epoch 56/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 128s 163ms/step - accuracy: 0.9217 - loss: 0.2264 - val_accuracy: 0.8931 - val_loss: 0.3506 - learning_rate: 5.0000e-04
# Epoch 57/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 128s 164ms/step - accuracy: 0.9183 - loss: 0.2337 - val_accuracy: 0.9090 - val_loss: 0.2926 - learning_rate: 5.0000e-04
# Epoch 58/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 127s 162ms/step - accuracy: 0.9226 - loss: 0.2241 - val_accuracy: 0.8992 - val_loss: 0.3440 - learning_rate: 5.0000e-04
# Epoch 59/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 128s 163ms/step - accuracy: 0.9209 - loss: 0.2264 - val_accuracy: 0.8983 - val_loss: 0.3338 - learning_rate: 5.0000e-04
# Epoch 60/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 128s 164ms/step - accuracy: 0.9224 - loss: 0.2189 - val_accuracy: 0.9070 - val_loss: 0.2966 - learning_rate: 5.0000e-04
# Epoch 61/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 128s 164ms/step - accuracy: 0.9219 - loss: 0.2259 - val_accuracy: 0.9067 - val_loss: 0.3055 - learning_rate: 5.0000e-04
# Epoch 62/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9233 - loss: 0.2143
# Epoch 62: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 129s 164ms/step - accuracy: 0.9233 - loss: 0.2143 - val_accuracy: 0.8984 - val_loss: 0.3336 - learning_rate: 5.0000e-04
# Epoch 63/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 131s 167ms/step - accuracy: 0.9265 - loss: 0.2075 - val_accuracy: 0.9071 - val_loss: 0.2994 - learning_rate: 2.5000e-04
# Epoch 64/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 130s 166ms/step - accuracy: 0.9308 - loss: 0.2001 - val_accuracy: 0.9047 - val_loss: 0.3160 - learning_rate: 2.5000e-04
# Epoch 65/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 130s 166ms/step - accuracy: 0.9280 - loss: 0.2035 - val_accuracy: 0.9044 - val_loss: 0.3230 - learning_rate: 2.5000e-04
# Epoch 66/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 134s 171ms/step - accuracy: 0.9295 - loss: 0.1978 - val_accuracy: 0.9039 - val_loss: 0.3193 - learning_rate: 2.5000e-04
# Epoch 67/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 134s 171ms/step - accuracy: 0.9322 - loss: 0.1936 - val_accuracy: 0.9130 - val_loss: 0.2918 - learning_rate: 2.5000e-04
# Epoch 68/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 133s 170ms/step - accuracy: 0.9302 - loss: 0.1958 - val_accuracy: 0.9079 - val_loss: 0.3106 - learning_rate: 2.5000e-04
# Epoch 69/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 133s 170ms/step - accuracy: 0.9323 - loss: 0.1929 - val_accuracy: 0.9065 - val_loss: 0.3068 - learning_rate: 2.5000e-04
# Epoch 70/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 134s 171ms/step - accuracy: 0.9342 - loss: 0.1923 - val_accuracy: 0.9120 - val_loss: 0.2905 - learning_rate: 2.5000e-04
# Epoch 71/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 133s 170ms/step - accuracy: 0.9325 - loss: 0.1943 - val_accuracy: 0.9089 - val_loss: 0.2992 - learning_rate: 2.5000e-04
# Epoch 72/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 137s 175ms/step - accuracy: 0.9335 - loss: 0.1892 - val_accuracy: 0.9172 - val_loss: 0.2750 - learning_rate: 2.5000e-04
# Epoch 73/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 140s 179ms/step - accuracy: 0.9354 - loss: 0.1884 - val_accuracy: 0.9148 - val_loss: 0.2900 - learning_rate: 2.5000e-04
# Epoch 74/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 134s 171ms/step - accuracy: 0.9347 - loss: 0.1844 - val_accuracy: 0.9129 - val_loss: 0.2962 - learning_rate: 2.5000e-04
# Epoch 75/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 134s 171ms/step - accuracy: 0.9349 - loss: 0.1785 - val_accuracy: 0.9125 - val_loss: 0.2962 - learning_rate: 2.5000e-04
# Epoch 76/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 136s 174ms/step - accuracy: 0.9349 - loss: 0.1855 - val_accuracy: 0.9081 - val_loss: 0.3139 - learning_rate: 2.5000e-04
# Epoch 77/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9360 - loss: 0.1813
# Epoch 77: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 136s 174ms/step - accuracy: 0.9360 - loss: 0.1813 - val_accuracy: 0.9090 - val_loss: 0.3167 - learning_rate: 2.5000e-04
# Epoch 78/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 136s 173ms/step - accuracy: 0.9378 - loss: 0.1782 - val_accuracy: 0.9155 - val_loss: 0.2898 - learning_rate: 1.2500e-04
# Epoch 79/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 155s 199ms/step - accuracy: 0.9384 - loss: 0.1752 - val_accuracy: 0.9110 - val_loss: 0.3029 - learning_rate: 1.2500e-04
# Epoch 80/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 162s 208ms/step - accuracy: 0.9383 - loss: 0.1756 - val_accuracy: 0.9096 - val_loss: 0.3034 - learning_rate: 1.2500e-04
# Epoch 81/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 165s 210ms/step - accuracy: 0.9392 - loss: 0.1731 - val_accuracy: 0.9125 - val_loss: 0.2975 - learning_rate: 1.2500e-04
# Epoch 82/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9407 - loss: 0.1655
# Epoch 82: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 163s 208ms/step - accuracy: 0.9407 - loss: 0.1655 - val_accuracy: 0.9169 - val_loss: 0.2807 - learning_rate: 1.2500e-04
# Epoch 83/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 160s 205ms/step - accuracy: 0.9435 - loss: 0.1621 - val_accuracy: 0.9113 - val_loss: 0.3042 - learning_rate: 6.2500e-05
# Epoch 84/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 161s 206ms/step - accuracy: 0.9416 - loss: 0.1678 - val_accuracy: 0.9130 - val_loss: 0.2950 - learning_rate: 6.2500e-05
# Epoch 85/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 161s 206ms/step - accuracy: 0.9415 - loss: 0.1644 - val_accuracy: 0.9129 - val_loss: 0.2985 - learning_rate: 6.2500e-05
# Epoch 86/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 166s 212ms/step - accuracy: 0.9432 - loss: 0.1653 - val_accuracy: 0.9128 - val_loss: 0.2953 - learning_rate: 6.2500e-05
# Epoch 87/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.9402 - loss: 0.1673
# Epoch 87: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 167s 214ms/step - accuracy: 0.9402 - loss: 0.1673 - val_accuracy: 0.9123 - val_loss: 0.2978 - learning_rate: 6.2500e-05
# Epoch 88/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 169s 215ms/step - accuracy: 0.9369 - loss: 0.1776 - val_accuracy: 0.9128 - val_loss: 0.2947 - learning_rate: 3.1250e-05
# Epoch 89/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 165s 211ms/step - accuracy: 0.9400 - loss: 0.1697 - val_accuracy: 0.9134 - val_loss: 0.2950 - learning_rate: 3.1250e-05
# Epoch 90/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 163s 209ms/step - accuracy: 0.9422 - loss: 0.1636 - val_accuracy: 0.9128 - val_loss: 0.2976 - learning_rate: 3.1250e-05
# Epoch 91/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 168s 215ms/step - accuracy: 0.9425 - loss: 0.1643 - val_accuracy: 0.9122 - val_loss: 0.3045 - learning_rate: 3.1250e-05
# Epoch 92/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.9414 - loss: 0.1615
# Epoch 92: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 166s 213ms/step - accuracy: 0.9414 - loss: 0.1615 - val_accuracy: 0.9141 - val_loss: 0.2940 - learning_rate: 3.1250e-05
# Epoch 93/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 165s 211ms/step - accuracy: 0.9432 - loss: 0.1629 - val_accuracy: 0.9134 - val_loss: 0.2982 - learning_rate: 1.5625e-05
# Epoch 94/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 148s 189ms/step - accuracy: 0.9440 - loss: 0.1582 - val_accuracy: 0.9128 - val_loss: 0.3027 - learning_rate: 1.5625e-05
# Epoch 95/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 145s 185ms/step - accuracy: 0.9417 - loss: 0.1676 - val_accuracy: 0.9132 - val_loss: 0.2987 - learning_rate: 1.5625e-05
# Epoch 96/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 142s 181ms/step - accuracy: 0.9412 - loss: 0.1632 - val_accuracy: 0.9133 - val_loss: 0.3003 - learning_rate: 1.5625e-05
# Epoch 97/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9429 - loss: 0.1650
# Epoch 97: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 142s 181ms/step - accuracy: 0.9429 - loss: 0.1649 - val_accuracy: 0.9134 - val_loss: 0.2965 - learning_rate: 1.5625e-05
# Epoch 98/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 143s 183ms/step - accuracy: 0.9445 - loss: 0.1607 - val_accuracy: 0.9133 - val_loss: 0.2969 - learning_rate: 7.8125e-06
# Epoch 99/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 143s 183ms/step - accuracy: 0.9427 - loss: 0.1602 - val_accuracy: 0.9141 - val_loss: 0.2964 - learning_rate: 7.8125e-06
# Epoch 100/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 144s 185ms/step - accuracy: 0.9442 - loss: 0.1602 - val_accuracy: 0.9132 - val_loss: 0.2975 - learning_rate: 7.8125e-06

# %%
plot_confusion_matrix(model, X, y, labels=labels)

# %%
plot_confusion_matrix(model, X_test, y_test, labels=labels)

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(X_test).argmax(axis=-1)

print("Classification Report on Test Set:")
print(classification_report(y_test, y_pred, target_names=labels, zero_division=0))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#     airplane       0.91      0.94      0.93      1000
#   automobile       0.94      0.97      0.96      1000
#         bird       0.94      0.86      0.90      1000
#          cat       0.86      0.80      0.83      1000
#         deer       0.90      0.94      0.92      1000
#          dog       0.88      0.85      0.87      1000
#         frog       0.89      0.97      0.93      1000
#        horse       0.94      0.94      0.94      1000
#         ship       0.96      0.95      0.95      1000
#        truck       0.94      0.95      0.94      1000
#
#     accuracy                           0.92     10000
#    macro avg       0.92      0.92      0.92     10000
# weighted avg       0.92      0.92      0.92     10000

# %%
from sklearn.metrics import balanced_accuracy_score

balanced_acc = balanced_accuracy_score(y_test, y_pred)

print(f"Balanced Accuracy: {balanced_acc:.4f}")
# Out:
# Balanced Accuracy: 0.9172

# %%
import matplotlib.pyplot as plt

history_dict = history.history

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history_dict['loss'], label='Train Loss')
plt.plot(history_dict['val_loss'], label='Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss over Epochs')
plt.legend()
plt.grid(True)

if 'accuracy' in history_dict:
    plt.subplot(1, 2, 2)
    plt.plot(history_dict['accuracy'], label='Train Accuracy')
    plt.plot(history_dict['val_accuracy'], label='Val Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Accuracy over Epochs')
    plt.legend()
    plt.grid(True)

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.models import load_model

model_path = r'C:\Users\maxim\NN\cifar_10\history\20250527-173534\model.keras'
model = load_model(model_path, compile=True)
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 32, 32, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 32, 32, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 32, 32, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 32, 32, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 16, 16, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 16, 16, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_2 (Activation)            │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 16, 16, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 16, 16, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_3 (Activation)            │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 8, 8, 256)           │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 8, 8, 256)           │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_4 (Activation)            │ (None, 8, 8, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 8, 8, 256)           │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 8, 8, 256)           │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_5 (Activation)            │ (None, 8, 8, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 4, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 4, 4, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 4096)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │       2,097,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_6 (Activation)            │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           5,130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 9,755,872 (37.22 MB)
#  Trainable params: 3,251,018 (12.40 MB)
#  Non-trainable params: 2,816 (11.00 KB)
#  Optimizer params: 6,502,038 (24.80 MB)
